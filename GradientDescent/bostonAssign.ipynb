# %% [markdown]
# ### fetching data and finding x and y from the data
# we are getting a data frame by function read_csv <br>
# the iloc is used to slice the dataframe and seprate x and y

# %%
import numpy as np
import pandas as pd
data = pd.read_csv("boston_x_y_train.csv")
x = data.iloc[:,0:13] 
y=data.iloc[:,13]
data
# Out:
#        # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT     Y
# ...

# %% [markdown]
# ### adding one extra column woth all the ones for c
# we have 13 columns initially for x in the database that means x depends on 13 variables , instaed to using c we add one extra column with all the ones

# %%
c=np.ones(x_in_arr.shape[0])
c.shape
print(x.shape)
x['c'] = c
x.shape
# Out:
# (379, 13)
# (379, 14)

# %% [markdown]
# ### we are converting the x and y into array
# here x is a 2d array of (379,13) and y is a 1d array

# %%
x_in_arr = np.array(x)
x_in_arr
y_in_arr = np.array(y)
x_in_arr.shape
# Out:
# (379, 14)

# %% [markdown]
# ### cost function
# formula of cost = (y-m1x1+m2x2+......)**2
# x and y are used as fetched

# %%
def cost(data, m):
    total_cost = 0
    N = len(data)
    for i in range(N):
        x = x_in_arr[i]
        y = y_in_arr[i]
        total_cost += (1/N)*((y - (m*x).sum())**2)
    return total_cost

# %% [markdown]
# ### step gradient
# first loop is for every row second id for columns , we are saying ki har row ke liye m_slope nikalo <br>
# now for every slope for each row multiply it by alpha using loop 3

# %%
def step_gradient(data,alpha,m):
    m_slope = np.zeros(14)
    N = len(data)
    for i in range(N):
        x = x_in_arr[i]
        y = y_in_arr[i]
        for j in range(14):
            m_slope[j]+=(-2/N)*(y - (m*x).sum())*x[j]
    
    # loop 3
    for j in range(14):
        m[j] = m[j]- alpha*m_slope[j]
    return m

# %%
def GD(data, num_iterations,alpha):
    m = np.zeros(14)
    for i in range(num_iterations):
        m = step_gradient(data,alpha,m)
        print(i, " Cost: ", cost(data, m))
    return m

# %%
def loadData() :
    alpha = 0.05
    num_iterations = 2000
    m = GD(data,num_iterations,alpha)
    return m

# %%
m =loadData()
slope = list(m)
# Out:
# 0  Cost:  472.10122053351836
# 1  Cost:  382.8463372957102
# 2  Cost:  313.04093073071647
# 3  Cost:  257.2511005568494
# 4  Cost:  212.4569924015233
# 5  Cost:  176.43798285190843
# 6  Cost:  147.44843721307797
# 7  Cost:  124.09750843427919
# 8  Cost:  105.27348291735812
# 9  Cost:  90.08660932257881
# 10  Cost:  77.82412766402773
# 11  Cost:  67.91459433977252
# 12  Cost:  59.89951114840237
# 13  Cost:  53.410732343825146
# 14  Cost:  48.15245305580118
# 15  Cost:  43.88683541423894
# 16  Cost:  40.42252661781744
# 17  Cost:  37.605478697873565
# 18  Cost:  35.31160218405039
# 19  Cost:  33.44088245909929
# 20  Cost:  31.912663875096964
# 21  Cost:  30.6618670411787
# 22  Cost:  29.635952481037464
# 23  Cost:  28.792481755531703
# 24  Cost:  28.09715723581849
# 25  Cost:  27.522245631775196
# 26  Cost:  27.045309415840354
# 27  Cost:  26.648185447218648
# 28  Cost:  26.316162194982844
# 29  Cost:  26.037316612323703
# 30  Cost:  25.80197942740555
# 31  Cost:  25.602303784465274
# ...

# %% [markdown]
# ### caclulating the y_prediction
# 1. fetching the xtest values  <br>
# 2.  converting it into np array
# 3. declaring a 1d array to store y_pred for every row
# 4. *Understanding loop*
#     for every row , calculate y using y = mx+c here c = 1 so mx only
#     now x is 2d nparray
# 5.  we added ypred.insert(0,14.09960678) because actual size should be 126 but because i used pd,read_csv i have to do like that
# 6 .savetxt is saving the result in the csv file

# %%
test_x = pd.read_csv("boston_x_test.csv")
N = len(test_x)
test_x['one'] = np.ones(N)
test_x = np.array(test_x)
ypred = []
for i in range(N):
    ans=0
    for j in range(len(slope)):
        ans+=slope[j]*test_x[i][j]
    ypred.append(ans)
ypred.insert(0,14.09960678)
ypred = pd.DataFrame(ypred)
np.savetxt("gradientdescent_assignment_boston.csv",ypred) 
ypred
# Out:
#              0
# 0    14.099607
# 1    29.033672
# 2    22.371645
# 3    24.477786
# 4    20.601672
# ..         ...
# 122  23.091397
# 123  25.018128
# 124  17.464934
# 125  20.737100
# 126  14.729937
#
# [127 rows x 1 columns]
